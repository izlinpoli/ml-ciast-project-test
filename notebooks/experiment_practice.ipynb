# %%
# Import Packages

import os,mlflow
import pandas as pd
import numpy as np
from sklearn import model_selection,preprocessing,datasets,metrics
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# 2. Data Preparation
# Data Loading
data = datasets.load_breast_cancer(as_frame=True)
df = data.frame
features = data.data
label = data.target
label_names = data.target_names

# %%
# 3. EDA
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  target                   569 non-null    int32
# dtypes: float64(30), int32(1)
# memory usage: 135.7 KB
# None
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension      target
# count               569.000000  569.000000
# mean                  0.083946    0.627417
# std                   0.018061    0.483918
# min                   0.055040    0.000000
# 25%                   0.071460    0.000000
# 50%                   0.080040    1.000000
# 75%                   0.092080    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %%
# check missing values and duplicate
print(df.isna().sum())
print(df.duplicated().sum())
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64
# 0

# %%
# 4. Data Spliting
SEED = 42
x_train, x_test, y_train, y_test = model_selection.train_test_split(features,label,train_size=0.8,shuffle=True,random_state=SEED)

# %%
# 5. Feature Scaling
standard_scaler = preprocessing.StandardScaler()
x_train = standard_scaler.fit_transform(x_train)
x_test = standard_scaler.transform(x_test)

# %%
# 6. Model Development -- do it with mlflow
# check current working directory
print(os.getcwd())
# Out:
# C:\Users\MSFRotPC07\Desktop\ciast_ml_master\ml-project-1

# %%
# Change current working directory based to bas project folder
os.chdir("..")
print(os.getcwd())
# Out:
# C:\Users\MSFRotPC07\Desktop\ciast_ml_master

# %%
# Just in case not go to the current directory. Use absolute path to change directory
os.chdir(r"C:\Users\MSFRotPC07\Desktop\ciast_ml_master\ml-project-1")
print(os.getcwd())
# Out:
# C:\Users\MSFRotPC07\Desktop\ciast_ml_master\ml-project-1

# %%
# Create an MLFlow Experiment
mlflow.create_experiment("breast_cancer_experiment")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Create an MLFlow Experiment
# ----> 2 mlflow.create_experiment("breast_cancer_experiment")
#
# File c:\Users\MSFRotPC07\anaconda3\envs\ciast_ai01\lib\site-packages\mlflow\tracking\fluent.py:1766, in create_experiment(name, artifact_location, tags)
#    1718 def create_experiment(
#    1719     name: str,
#    1720     artifact_location: Optional[str] = None,
#    1721     tags: Optional[Dict[str, Any]] = None,
#    1722 ) -> str:
#    1723     """
#    1724     Create an experiment.
#    1725
#    (...)
#    1764         Creation timestamp: 1662004217511
#    1765     """
# -> 1766     return MlflowClient().create_experiment(name, artifact_location, tags)
#
# File c:\Users\MSFRotPC07\anaconda3\envs\ciast_ai01\lib\site-packages\mlflow\tracking\client.py:1294, in MlflowClient.create_experiment(self, name, artifact_location, tags)
#    1242 def create_experiment(
#    1243     self,
#    1244     name: str,
#    1245     artifact_location: Optional[str] = None,
#    1246     tags: Optional[Dict[str, Any]] = None,
#    1247 ) -> str:
#    1248     """Create an experiment.
#    1249
#    1250     Args:
#    (...)
#    1292
#    1293     """
# -> 1294     return self._tracking_client.create_experiment(name, artifact_location, tags)
#
# File c:\Users\MSFRotPC07\anaconda3\envs\ciast_ai01\lib\site-packages\mlflow\tracking\_tracking_service\client.py:501, in TrackingServiceClient.create_experiment(self, name, artifact_location, tags)
#     487 """Create an experiment.
#     488
#     489 Args:
#    (...)
#     498
#     499 """
#     500 _validate_experiment_artifact_location(artifact_location)
# --> 501 return self.store.create_experiment(
#     502     name=name,
#     503     artifact_location=artifact_location,
#     504     tags=[ExperimentTag(key, value) for (key, value) in tags.items()] if tags else [],
#     505 )
#
# File c:\Users\MSFRotPC07\anaconda3\envs\ciast_ai01\lib\site-packages\mlflow\store\tracking\file_store.py:394, in FileStore.create_experiment(self, name, artifact_location, tags)
#     392 self._check_root_dir()
#     393 _validate_experiment_name(name)
# --> 394 self._validate_experiment_does_not_exist(name)
#     395 experiment_id = _generate_unique_integer_id()
#     396 return self._create_experiment_with_id(name, str(experiment_id), artifact_location, tags)
#
# File c:\Users\MSFRotPC07\anaconda3\envs\ciast_ai01\lib\site-packages\mlflow\store\tracking\file_store.py:386, in FileStore._validate_experiment_does_not_exist(self, name)
#     378     raise MlflowException(
#     379         "Experiment '%s' already exists in deleted state. "
#     380         "You can restore the experiment, or permanently delete the experiment "
#    (...)
#     383         databricks_pb2.RESOURCE_ALREADY_EXISTS,
#     384     )
#     385 else:
# --> 386     raise MlflowException(
#     387         f"Experiment '{experiment.name}' already exists.",
#     388         databricks_pb2.RESOURCE_ALREADY_EXISTS,
#     389     )
#
# MlflowException: Experiment 'breast_cancer_experiment' already exists.

# %%
# Use the experiment
mlflow.set_experiment("breast_cancer_experiment")

# Set experiment tag
mlflow.set_experiment_tag("mlfow_version","2.15.1")

# %%
# Carry out ML run and log the necessary artifacts and results
with mlflow.start_run():
    # Setup for model training
    svc_kernel = 'rbf'
    model = SVC(kernel=svc_kernel)
    model.fit(x_train,y_train)
    # Model Evaluation
    predictions = model.predict(x_test)
    accuracy = metrics.accuracy_score(y_test,predictions)
    precision = metrics.precision_score(y_test,predictions)
    recall = metrics.recall_score(y_test,predictions)
    f1 = metrics.f1_score(y_test,predictions)
    # Logging
    # (A) Log the metrics
    mlflow.log_metrics({
        'Test Accuracy': accuracy,
        'Test Precision': precision,
        'Test Recall': recall,
        'Test F1': f1
    })
    # (B) Log the parameter used
    mlflow.log_param('kernel',svc_kernel)

# %%
# Test with orther kernel

kernel_list = ['linear','poly','sigmoid']

for kernel in kernel_list:
    with mlflow.start_run():
        # Setup for model training
        model = SVC(kernel=kernel)
        model.fit(x_train,y_train)
        # Model Evaluation
        predictions = model.predict(x_test)
        accuracy = metrics.accuracy_score(y_test,predictions)
        precision = metrics.precision_score(y_test,predictions)
        recall = metrics.recall_score(y_test,predictions)
        f1 = metrics.f1_score(y_test,predictions)
        # Logging
        # (A) Log the metrics
        mlflow.log_metrics({
            'Test Accuracy': accuracy,
            'Test Precision': precision,
            'Test Recall': recall,
            'Test F1': f1
        })
        # (B) Log the parameter used
        mlflow.log_param('kernel',kernel)

# %%
# Use auto log instead for the logging of the run 
with mlflow.start_run(run_name="decision_tree_1"):
    # enable autolog -> only for train data
    mlflow.autolog()
    #Train the model
    model = DecisionTreeClassifier()
    model.fit(x_train,y_train)
# Out:
# 2024/08/07 16:51:34 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/08/07 16:51:34 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2024/08/07 16:51:43 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\MSFRotPC07\anaconda3\envs\ciast_ai01\lib\site-packages\_distutils_hack\__init__.py:26: UserWarning: Setuptools is replacing distutils."

# %%
model
# Out:
# DecisionTreeClassifier()
